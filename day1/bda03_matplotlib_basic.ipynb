# %% [markdown]
# ### 맷플롯립 기초
# - 차트 시각화 라이브러리
#
# #### 맷플롯립 설치
# ```shell
# !pip install matplotlib
# ```

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %% [markdown]
# #### Seaborn 설치
# ```shell
# !pip install seaborn
# ```

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/294.9 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 3.6 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### 맷플롭립은 한글깨짐
# - 나눔폰트 옵션 사용
# - 폰트관리자 설정

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import warnings

# 나눔폰트 경로
font_path = 'C:/Windows/Fonts/NanumGothic.ttf'
font = font_manager.FontProperties(fname=font_path, size=10).get_name()

# 경고 메시지 무시
warnings.simplefilter('ignore')

# 기본 폰트 설정
plt.rcParams['font.family'] = font
# 기본 폰트 사이즈
plt.rcParams['font.size'] = 14
# 기본 차트 사이즈 변경
plt.rcParams['figure.figsize'] = (8, 6)
# 기본 그리드 표시
plt.rcParams['axes.grid'] = True
# 한글화 후 마이너스 표시 네모를 정상 출력
plt.rcParams['axes.unicode_minus'] = False

# %%
data = np.random.rand(50) # 랜덤 표준정규분포값 50개를 만듬
data
# Out:
# array([0.99251386, 0.99652803, 0.14066292, 0.87372615, 0.48859818,
#        0.05049141, 0.41460473, 0.06524316, 0.7076834 , 0.95532392,
#        0.88758312, 0.01298864, 0.79834882, 0.79084752, 0.69648231,
#        0.24554369, 0.05954864, 0.22972867, 0.44074146, 0.30919788,
#        0.75548827, 0.9117691 , 0.40494135, 0.31968889, 0.52338887,
#        0.98935374, 0.74667876, 0.75623437, 0.39596524, 0.93202771,
#        0.50825279, 0.9636988 , 0.74489942, 0.51102536, 0.03412584,
#        0.65456308, 0.74391326, 0.17031625, 0.66208863, 0.99181305,
#        0.59511088, 0.91989533, 0.2073331 , 0.78488667, 0.60891031,
#        0.96134655, 0.13996761, 0.59901864, 0.97186606, 0.9458571 ])

# %%
np.random.randint(1,20,size=50)
# Out:
# array([14, 18,  4,  6,  3,  5, 19, 19, 12, 17,  9, 17,  3, 10, 17, 15, 15,
#        19, 14, 17,  3, 14,  4,  3,  5,  1,  4, 12,  8, 12,  1, 10, 15, 17,
#        18, 19,  7,  8, 15, 12,  5,  7,  5,  2,  6,  5, 10, 14,  7, 12])

# %%
## 차트 생성
plt.plot(np.random.randn(50), label='겨울기온')
plt.title('변화값')
plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import seaborn as sns

#style => dark, darkgrid, white, ticks
# Seaboarn 사용시는 나눔고딕 안됨. 맑은 고딕
#sns.set(font='Malgum Gothic', rc={'axes.unicode_minus':False}, style='')
sns.set(font=font, rc={'axes.unicode_minus': False}, style='darkgrid')

# %%
## 차트 생성
#sns.set_style('darkgrid')
plt.plot(np.random.randn(50), label='겨울기온')
plt.title('변화값')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ##### 판다스로 읽은 데이터 차트화

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/sample_2.csv')
df
# Out:
#    Unnamed: 0 국적코드  성별    입국객수    전년동기
# 0           0  A01  남성  106320   85815
# 1           1  A01  여성  191436  125241
# 2           2  A31  남성     319     299
# 3           3  A31  여성      42      54
# 4           4  A18  남성  158912  124486
# 5           5  A18  여성  232943  163466

# %%
df[['성별', '입국객수']].plot()
plt.show()

# %%
# 히스토그램
df['입국객수'].hist(bins=5)
plt.title('2019년 10월 입국객수')
plt.show()

# %%
# 스캐터차트
x = np.random.randint(-100, 100, 50) # ~100에서 100사이에 50개만 랜덤
y = np.random.randint(-200, 200, 50) # ~100
size = np.random.randint(-200, 200, 50)
color = np.random.randint(0, 100, 50)

plt.scatter(x, y, s=size, c=color, alpha=0.5)
plt.title('온도(화씨)')
plt.colorbar()
plt.show()

# %%
## 파이차트
size = [2441, 2312, 1031, 1233]
label = ['A', 'B', 'AB', 'O']
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']

plt.axis('equal') # 가로축, 세로축 스케일 동일
plt.pie(size, labels=label, autopct='%.1f%%', explode=(0,0,0.1,0), colors=color)
plt.legend(loc='lower left')
plt.title('혈액형별 인구율')
plt.show()
